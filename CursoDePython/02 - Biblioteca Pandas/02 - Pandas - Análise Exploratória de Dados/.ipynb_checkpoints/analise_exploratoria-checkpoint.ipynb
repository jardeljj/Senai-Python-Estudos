# %% [markdown]
# # Análise Exploratória
#
# Vamos aprender a como utilizar as principais funcionalidades do Pandas para fazer uma análise exploratória inicial dos dados.
#
# A fase de análise exploratória é uma etapa muito importante dentro da análise de dados, pois é nela que vamos entender melhor os dados que iremos analisar e verificar se eles foram carregados corretamente.
#
# **Site oficial:** [https://pandas.pydata.org/](https://pandas.pydata.org/)
#
# **Documentação oficial:** [https://pandas.pydata.org/docs/](https://pandas.pydata.org/docs/)

# %% [markdown]
# # Carregando o arquivo CSV
#
# Vamos utilizar nos nossos exemplos o arquivo `base_vendas.csv`, que é uma base de vendas fictícia.

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/base_vendas.csv')

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %% [markdown]
# # DataFrame
#
# - Estrutura de dados do Pandas
# - É uma matriz - possui 2 dimensões (linhas e colunas)
# - Pode ter vários tipos de dados, mas cada coluna possui apenas um tipo
# - É mutável
# - É composto por:
#     - Colunas
#     - Índices
#     - Valores

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_copia = df

# %%
df_copia.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
type(df_copia)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Series
#
# Estrutura unidimensional de dados, composta por índices e valores.

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
df['nome_loja']
# Out:
# 0       Loja Matriz
# 1       Loja Matriz
# 2       Loja Matriz
# 3       Loja Matriz
# 4       Loja Matriz
#            ...
# 2995      Filial ES
# 2996      Filial ES
# 2997      Filial ES
# 2998      Filial ES
# 2999      Filial ES
# Name: nome_loja, Length: 3000, dtype: object

# %%
type(df['nome_loja'])
# Out:
# pandas.core.series.Series

# %%
type(df['Categoria'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Index
#
# Serve para indexar e organizar os elementos de um DataFrame.
#
# - é homogêneo
# - não precisa ter necessariamente valores únicos
# - pode ser criado automaticamente pelo Pandas, especificado no momento do carregamento dos dados ou alterado depois

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %% [markdown]
# # Columns
#
# Rótulo (nome) da coluna do DataFrame.

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
df.columns
# Out:
# Index(['matricula_funcionario', 'Nome Funcionario', 'Cargo', 'codigo_loja',
#        'nome_loja', 'codigo_produto', 'descricao_produto', 'Categoria',
#        'preco_custo', 'valor_unitario', 'quantidade', 'comissao', 'dt_venda',
#        'dt_entrega'],
#       dtype='object')

# %% [markdown]
# # Values
#
# Valores do DataFrame representados por um array Numpy.
#
# - Documentação oficial recomenda utilizar o método **to_numpy()** ao invés da propriedade **values**.

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
df.values
# Out:
# array([[123456111, 'José Maria', 'Vendedor', ..., nan,
#         '28/09/2020 16:19', '05/10/2020 16:31'],
#        [123456111, 'José Maria', 'Vendedor', ..., nan,
#         '07/03/2020 12:47', '08/03/2020 12:47'],
#        [123456111, 'José Maria', 'Vendedor', ..., nan,
#         '21/04/2019 10:48', '23/04/2019 15:55'],
#        ...,
#        [123457113, 'Victor Hugo', 'Vendedor', ..., nan,
#         '08/08/2020 14:46', '09/08/2020 14:07'],
#        [123457113, 'Victor Hugo', 'Vendedor', ..., nan,
#         '19/12/2019 09:21', '19/12/2019 10:51'],
#        [123457113, 'Victor Hugo', 'Vendedor', ..., '0,09',
#         '18/03/2019 15:40', '23/03/2019 17:52']], dtype=object)

# %%
df.to_numpy()
# Out:
# array([[123456111, 'José Maria', 'Vendedor', ..., nan,
#         '28/09/2020 16:19', '05/10/2020 16:31'],
#        [123456111, 'José Maria', 'Vendedor', ..., nan,
#         '07/03/2020 12:47', '08/03/2020 12:47'],
#        [123456111, 'José Maria', 'Vendedor', ..., nan,
#         '21/04/2019 10:48', '23/04/2019 15:55'],
#        ...,
#        [123457113, 'Victor Hugo', 'Vendedor', ..., nan,
#         '08/08/2020 14:46', '09/08/2020 14:07'],
#        [123457113, 'Victor Hugo', 'Vendedor', ..., nan,
#         '19/12/2019 09:21', '19/12/2019 10:51'],
#        [123457113, 'Victor Hugo', 'Vendedor', ..., '0,09',
#         '18/03/2019 15:40', '23/03/2019 17:52']], dtype=object)

# %% [markdown]
# # Métodos e propriedades

# %% [markdown]
# ## head()
#
# Lista as primeiras linhas do DataFrame

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %% [markdown]
# ## tail()
#
# Lista as últimas linhas do DataFrame

# %%
df.tail()
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  nome_loja  \
# 2995              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2996              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2997              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2998              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2999              123457113      Victor Hugo  Vendedor       CL004  Filial ES
#
#       codigo_produto    descricao_produto         Categoria preco_custo  \
# 2995           10006      Aspirador de pó              Casa        88,9
# 2996           10011       Liquidificador           Cozinha        59,9
# 2997           10007            Batedeira           Cozinha        49,9
# 2998           10010  Fritadeira elétrica           Cozinha       187,9
# 2999           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#      valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 2995          189,9           3      NaN  04/11/2019 15:40  05/11/2019 10:40
# 2996          142,4           3      NaN  24/06/2019 09:04  24/06/2019 10:50
# 2997           95,9           3      NaN  08/08/2020 14:46  09/08/2020 14:07
# 2998            340           3      NaN  19/12/2019 09:21  19/12/2019 10:51
# 2999         1709,1           3     0,09  18/03/2019 15:40  23/03/2019 17:52

# %% [markdown]
# ## shape
#
# Propriedade que mostra as dimensões do DataFrame

# %%
df.shape
# Out:
# (3000, 14)

# %%
type(df.shape)
# Out:
# tuple

# %%
total_linhas = df.shape[0]

# %%
print(total_linhas)
# Out:
# 3000

# %%
total_colunas = df.shape[1]
print(total_colunas)
# Out:
# 14

# %% [markdown]
# ## info()
#
# Mostra informações sobre o DataFrame, como o tipo de dados das colunas.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   matricula_funcionario  3000 non-null   int64
#  1   Nome Funcionario       3000 non-null   object
#  2   Cargo                  3000 non-null   object
#  3   codigo_loja            3000 non-null   object
#  4   nome_loja              3000 non-null   object
#  5   codigo_produto         3000 non-null   int64
#  6   descricao_produto      3000 non-null   object
#  7   Categoria              3000 non-null   object
#  8   preco_custo            3000 non-null   object
#  9   valor_unitario         3000 non-null   object
#  10  quantidade             3000 non-null   int64
#  11  comissao               159 non-null    object
#  12  dt_venda               3000 non-null   object
#  13  dt_entrega             3000 non-null   object
# dtypes: int64(3), object(11)
# memory usage: 328.2+ KB

# %% [markdown]
# ## describe()
#
# Mostra estatísticas descritivas das colunas quantitativas do DataFrame.

# %%
df.describe().T.round(1)
# Out:
#                         count         mean    std          min          25%  \
# matricula_funcionario  3000.0  123456680.8  349.0  123456111.0  123456333.0
# codigo_produto         3000.0      10010.5    5.8      10001.0      10006.0
# quantidade             3000.0          2.5    1.1          1.0          1.0
#
#                                50%          75%          max
# matricula_funcionario  123456666.0  123456999.0  123457113.0
# codigo_produto             10011.0      10015.0      10020.0
# quantidade                     2.0          3.0          4.0

# %%
df['codigo_produto'].describe().round(2)
# Out:
# count     3000.00
# mean     10010.47
# std          5.77
# min      10001.00
# 25%      10006.00
# 50%      10011.00
# 75%      10015.00
# max      10020.00
# Name: codigo_produto, dtype: float64

# %% [markdown]
# ## isna() / isnull()
#
# Os dois métodos são equivalentes. Verificam se existem valores faltantes do DataFrame.

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
df.isnull().sum()
# Out:
# matricula_funcionario       0
# Nome Funcionario            0
# Cargo                       0
# codigo_loja                 0
# nome_loja                   0
# codigo_produto              0
# descricao_produto           0
# Categoria                   0
# preco_custo                 0
# valor_unitario              0
# quantidade                  0
# comissao                 2841
# dt_venda                    0
# dt_entrega                  0
# dtype: int64

# %%
df.isna().sum() / df.shape[0] * 100
# Out:
# matricula_funcionario     0.0
# Nome Funcionario          0.0
# Cargo                     0.0
# codigo_loja               0.0
# nome_loja                 0.0
# codigo_produto            0.0
# descricao_produto         0.0
# Categoria                 0.0
# preco_custo               0.0
# valor_unitario            0.0
# quantidade                0.0
# comissao                 94.7
# dt_venda                  0.0
# dt_entrega                0.0
# dtype: float64

# %% [markdown]
# ## unique() e nunique()
#
# **nunique():** retorna a quantidade de elementos únicos.
#
# **unique():** retorna os elementos únicos

# %%
df.nunique()
# Out:
# matricula_funcionario      12
# Nome Funcionario           12
# Cargo                       1
# codigo_loja                 4
# nome_loja                   4
# codigo_produto             20
# descricao_produto          20
# Categoria                   4
# preco_custo                20
# valor_unitario             19
# quantidade                  4
# comissao                    4
# dt_venda                 2994
# dt_entrega               2989
# dtype: int64

# %%
df['matricula_funcionario'].nunique()
# Out:
# 12

# %%
df['matricula_funcionario'].unique()
# Out:
# array([123456111, 123456222, 123456333, 123456555, 123456444, 123456666,
#        123456999, 123456777, 123456888, 123457112, 123457111, 123457113],
#       dtype=int64)

# %%
df['nome_loja'].unique()
# Out:
# array(['Loja Matriz', 'Filial MG', 'Filial SP', 'Filial ES'], dtype=object)

# %%
# DataFrame não possui método unique() - apenas as Series
df.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35460/1660334235.py in <module>
# ----> 1 df.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %% [markdown]
# # Acessando linhas e colunas de um DataFrame

# %% [markdown]
# ## Acessando colunas

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
df['matricula_funcionario'].head()
# Out:
# 0    123456111
# 1    123456111
# 2    123456111
# 3    123456111
# 4    123456111
# Name: matricula_funcionario, dtype: int64

# %%
df.matricula_funcionario
# Out:
# 0       123456111
# 1       123456111
# 2       123456111
# 3       123456111
# 4       123456111
#           ...
# 2995    123457113
# 2996    123457113
# 2997    123457113
# 2998    123457113
# 2999    123457113
# Name: matricula_funcionario, Length: 3000, dtype: int64

# %%
df['Nome Funcionario']
# Out:
# 0        José Maria
# 1        José Maria
# 2        José Maria
# 3        José Maria
# 4        José Maria
#            ...
# 2995    Victor Hugo
# 2996    Victor Hugo
# 2997    Victor Hugo
# 2998    Victor Hugo
# 2999    Victor Hugo
# Name: Nome Funcionario, Length: 3000, dtype: object

# %%
df.Nome Funcionario
# Out:
#   File "C:\Users\vinil\AppData\Local\Temp/ipykernel_35460/2575889147.py", line 1
#     df.Nome Funcionario
#             ^
# SyntaxError: invalid syntax

# %%
# Acessar várias colunas
df[ ['matricula_funcionario', 'Nome Funcionario', 'valor_unitario'] ]
# Out:
#       matricula_funcionario Nome Funcionario valor_unitario
# 0                 123456111       José Maria          404,1
# 1                 123456111       José Maria          249,9
# 2                 123456111       José Maria         1346,9
# 3                 123456111       José Maria         1676,9
# 4                 123456111       José Maria         1709,1
# ...                     ...              ...            ...
# 2995              123457113      Victor Hugo          189,9
# 2996              123457113      Victor Hugo          142,4
# 2997              123457113      Victor Hugo           95,9
# 2998              123457113      Victor Hugo            340
# 2999              123457113      Victor Hugo         1709,1
#
# [3000 rows x 3 columns]

# %%
colunas = ['matricula_funcionario', 'Nome Funcionario', 'valor_unitario']
df[colunas]
# Out:
#       matricula_funcionario Nome Funcionario valor_unitario
# 0                 123456111       José Maria          404,1
# 1                 123456111       José Maria          249,9
# 2                 123456111       José Maria         1346,9
# 3                 123456111       José Maria         1676,9
# 4                 123456111       José Maria         1709,1
# ...                     ...              ...            ...
# 2995              123457113      Victor Hugo          189,9
# 2996              123457113      Victor Hugo          142,4
# 2997              123457113      Victor Hugo           95,9
# 2998              123457113      Victor Hugo            340
# 2999              123457113      Victor Hugo         1709,1
#
# [3000 rows x 3 columns]

# %% [markdown]
# ## Método loc
#
# Acessa um grupo de linhas e colunas através do seu **rótulo** (label).
#
# ```python
# df.loc['rotulo_linha', 'rotulo_coluna']
# ```

# %%
animais = {
    'animal': ['cobra', 'tigre', 'guepardo'],
    'velocidade': [6, 30, 60],
    'veneno': ['sim', 'não', 'não'],
    'tipo': ['réptil', 'felino', 'felino']
}

df_animais = pd.DataFrame(animais)

# %%
df_animais.set_index('animal', inplace=True)

# %%
df_animais
# Out:
#           velocidade veneno    tipo
# animal
# cobra              6    sim  réptil
# tigre             30    não  felino
# guepardo          60    não  felino

# %%
df_animais.loc['cobra', 'tipo']
# Out:
# 'réptil'

# %%
df_animais.loc['guepardo',['veneno', 'tipo']]
# Out:
# veneno       não
# tipo      felino
# Name: guepardo, dtype: object

# %%
df_animais.loc['cobra':'tigre', 'velocidade':'tipo']
# Out:
#         velocidade veneno    tipo
# animal
# cobra            6    sim  réptil
# tigre           30    não  felino

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52

# %%
# acessando as 10 primeiras linhas:
df.loc[:10 , 'Cargo':'descricao_produto']
# Out:
#        Cargo codigo_loja    nome_loja  codigo_produto    descricao_produto
# 0   Vendedor       CL001  Loja Matriz           10013                Fogão
# 1   Vendedor       CL001  Loja Matriz           10018              Colchão
# 2   Vendedor       CL001  Loja Matriz           10014            Geladeira
# 3   Vendedor       CL001  Loja Matriz           10001           Smartphone
# 4   Vendedor       CL001  Loja Matriz           10004  Máquina Lavar Roupa
# 5   Vendedor       CL001  Loja Matriz           10010  Fritadeira elétrica
# 6   Vendedor       CL001  Loja Matriz           10014            Geladeira
# 7   Vendedor       CL001  Loja Matriz           10006      Aspirador de pó
# 8   Vendedor       CL001  Loja Matriz           10010  Fritadeira elétrica
# 9   Vendedor       CL001  Loja Matriz           10017             Cama Box
# 10  Vendedor       CL001  Loja Matriz           10003            Televisão

# %%
# acessando as 10 primeiras linhas:
colunas = ['Cargo','descricao_produto']
df.loc[:10 , colunas]
# Out:
#        Cargo    descricao_produto
# 0   Vendedor                Fogão
# 1   Vendedor              Colchão
# 2   Vendedor            Geladeira
# 3   Vendedor           Smartphone
# 4   Vendedor  Máquina Lavar Roupa
# 5   Vendedor  Fritadeira elétrica
# 6   Vendedor            Geladeira
# 7   Vendedor      Aspirador de pó
# 8   Vendedor  Fritadeira elétrica
# 9   Vendedor             Cama Box
# 10  Vendedor            Televisão

# %% [markdown]
# ## Método iloc
#
# Acessa um grupo de linhas e colunas através da sua **posição**.

# %%
df_animais
# Out:
#           velocidade veneno    tipo
# animal
# cobra              6    sim  réptil
# tigre             30    não  felino
# guepardo          60    não  felino

# %%
# acessando a primeira linha
df_animais.iloc[0]
# Out:
# velocidade         6
# veneno           sim
# tipo          réptil
# Name: cobra, dtype: object

# %%
# acessando linhas e colunas
df_animais.iloc[0, [0,2]]
# Out:
# velocidade         6
# tipo          réptil
# Name: cobra, dtype: object

# %%
# slicing - 10 primeiras linhas
df.iloc[:10]
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 5              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 6              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 7              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 8              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 9              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
# 5           10010  Fritadeira elétrica           Cozinha       187,9
# 6           10014            Geladeira  Eletrodomésticos       699,9
# 7           10006      Aspirador de pó              Casa        88,9
# 8           10010  Fritadeira elétrica           Cozinha       187,9
# 9           10017             Cama Box              Casa      1189,9
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 0          404,1           1      NaN  28/09/2020 16:19  05/10/2020 16:31
# 1          249,9           1      NaN  07/03/2020 12:47  08/03/2020 12:47
# 2         1346,9           1      NaN  21/04/2019 10:48  23/04/2019 15:55
# 3         1676,9           1      NaN  07/05/2020 17:59  08/05/2020 14:31
# 4         1709,1           1     0,05  14/08/2019 16:56  19/08/2019 15:52
# 5            340           1      NaN  10/07/2019 15:11  11/07/2019 14:30
# 6         1346,9           1      NaN  26/06/2019 11:03  28/06/2019 13:37
# 7          189,9           1      NaN  15/03/2020 13:00  16/03/2020 11:15
# 8            340           1      NaN  15/08/2020 11:36  15/08/2020 14:22
# 9         1899,5           1      NaN  06/03/2019 13:01  11/03/2019 12:01

# %%
# slicing 10 últimas linhas
df.iloc[-10:]
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  nome_loja  \
# 2990              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2991              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2992              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2993              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2994              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2995              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2996              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2997              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2998              123457113      Victor Hugo  Vendedor       CL004  Filial ES
# 2999              123457113      Victor Hugo  Vendedor       CL004  Filial ES
#
#       codigo_produto    descricao_produto         Categoria preco_custo  \
# 2990           10014            Geladeira  Eletrodomésticos       699,9
# 2991           10016         Guarda Roupa              Casa       489,9
# 2992           10010  Fritadeira elétrica           Cozinha       187,9
# 2993           10001           Smartphone       Eletrônicos       899,9
# 2994           10001           Smartphone       Eletrônicos       899,9
# 2995           10006      Aspirador de pó              Casa        88,9
# 2996           10011       Liquidificador           Cozinha        59,9
# 2997           10007            Batedeira           Cozinha        49,9
# 2998           10010  Fritadeira elétrica           Cozinha       187,9
# 2999           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#      valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 2990         1346,9           3      NaN  04/12/2020 13:24  10/12/2020 11:05
# 2991            999           3      NaN  13/06/2020 16:58  15/06/2020 17:41
# 2992            340           3      NaN  02/07/2019 16:56  03/07/2019 09:27
# 2993         1676,9           3      NaN  18/12/2019 17:59  19/12/2019 16:33
# 2994         1676,9           3      NaN  26/01/2019 16:06  26/01/2019 16:16
# 2995          189,9           3      NaN  04/11/2019 15:40  05/11/2019 10:40
# 2996          142,4           3      NaN  24/06/2019 09:04  24/06/2019 10:50
# 2997           95,9           3      NaN  08/08/2020 14:46  09/08/2020 14:07
# 2998            340           3      NaN  19/12/2019 09:21  19/12/2019 10:51
# 2999         1709,1           3     0,09  18/03/2019 15:40  23/03/2019 17:52

# %%
# slicing linhas e colunas
df.iloc[10:21, 0:5]
# Out:
#     matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja
# 10              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 11              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 12              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 13              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 14              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 15              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 16              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 17              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 18              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 19              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 20              123456111       José Maria  Vendedor       CL001  Loja Matriz
