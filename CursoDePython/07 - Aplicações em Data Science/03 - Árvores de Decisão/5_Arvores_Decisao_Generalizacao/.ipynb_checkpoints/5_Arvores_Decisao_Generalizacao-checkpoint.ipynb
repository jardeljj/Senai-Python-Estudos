# %% [markdown]
# # Árvores de Decisão: Capacidade de Generalização

# %% [markdown]
# ## Importação das bibliotecas

# %%
# Pacotes de preparação dos dados
import pandas as pd
import numpy as np

# Pacotes gráficos
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from dtreeviz.trees import dtreeviz

# Pacotes de modelagem
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# Módulo de Análise Exploratória
import aed

# %% [markdown]
# ## Importação da base de dados

# %%
df_rh = pd.read_csv('base_funcionarios.csv', sep=';')
df_rh.head()
# Out:
#    Salario  Anos_Educ_Superior  Tempo_Empresa
# 0   5517.4                   3              3
# 1   6399.9                   4              6
# 2   6206.7                   6              3
# 3   6060.6                   4              5
# 4   6122.7                   2              9

# %% [markdown]
# ## Desenvolvimento do Modelo: Árvores de Decisão

# %% [markdown]
# ### Definição do *Target* e das *Features*

# %%
# Target (variável resposta)
y = df_rh['Salario']

# Features (variáveis explicativas)
x = df_rh.drop('Salario', axis = 1)

# %% [markdown]
# ### Divisão das bases em Treino e Teste

# %%
df_rh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Salario             46 non-null     float64
#  1   Anos_Educ_Superior  46 non-null     int64
#  2   Tempo_Empresa       46 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 1.2 KB

# %%
46*0.30
# Out:
# 13.799999999999999

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.30,
                                                    random_state=42)

# %%
x_train.shape
# Out:
# (32, 2)

# %%
x_test.shape
# Out:
# (14, 2)

# %% [markdown]
# ### Treinamento da Árvore de Decisão

# %%
modelo_salario = DecisionTreeRegressor(max_depth=2, 
                                       min_samples_leaf=5,
                                       random_state=42)
modelo_salario.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, min_samples_leaf=5, random_state=42)

# %% [markdown]
# ### Avaliação do modelo treinado

# %% [markdown]
# #### Interpretação do Modelo

# %%
matplotlib.use('module://ipykernel.pylab.backend_inline')
fig = plt.figure(figsize=(15,10))

features = list(x.columns)
tree.plot_tree(modelo_salario,
               feature_names=features,
               filled=True);
plt.title("Salário de Colaboradores\n Utilizando Árvores de Decisão");
plt.show()

# %%
viz = dtreeviz(tree_model=modelo_salario, 
               x_data=x_train, y_data=y_train, 
               target_name='Salario',
               feature_names=features,
               scale=2.0)
viz

# %% [markdown]
# #### Desempenho do Modelo: Treino

# %%
# Cálculo do desempenho do modelo: R²
r2_score(y_train, modelo_salario.predict(x_train))
# Out:
# 0.6304067355640544

# %% [markdown]
# #### Desempenho do Modelo: Teste

# %%
# Cálculo do desempenho do modelo: R²
r2_score(y_test, modelo_salario.predict(x_test))
# Out:
# 0.20795772778781418

# %% [markdown]
# ### Criação de uma função para simplificar o processo

# %%
def treina_arvore_regressao(x_train, y_train, x_test, y_test, max_d, min_s):

    modelo = DecisionTreeRegressor(max_depth=max_d,
                                   min_samples_leaf=min_s,
                                   random_state=42)
    modelo.fit(x_train, y_train)
    
    y_predito_train = modelo.predict(x_train)
    y_predito_test = modelo.predict(x_test)
    
    # Cálculo do Desempenho
    r2_train = r2_score(y_train, y_predito_train)
    r2_test = r2_score(y_test, y_predito_test)
    
    return modelo, (r2_train, r2_test)

# %%
treina_arvore_regressao(x_train, y_train, x_test, y_test, 3, 5)
# Out:
# (DecisionTreeRegressor(max_depth=3, min_samples_leaf=5, random_state=42),
#  (0.6620135956979547, 0.4037665885350076))
