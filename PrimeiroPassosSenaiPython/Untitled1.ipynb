# %%
import pandas as pd

# %%
df = pd.read_csv('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/base_vendas_ponto_virgula.csv', sep=';')

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df.tail(2)
# Out:
#     matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 98              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 99              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#     codigo_produto         descricao_produto Categoria preco_custo  \
# 98           10012  Processador de alimentos   Cozinha         110
# 99           10018                   Colchão      Casa       109,9
#
#    valor_unitario  quantidade comissao          dt_venda        dt_entrega
# 98          189,9           3      NaN  30/09/2019 16:49  01/10/2019 14:55
# 99          249,9           3      NaN  08/11/2020 14:32  09/11/2020 09:48

# %%
df = pd.read_csv('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/base_vendas_tab.tsv', sep='\t')

# %%
df.head()
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
#    codigo_produto    descricao_produto         Categoria preco_custo  \
# 0           10013                Fogão  Eletrodomésticos       210,9
# 1           10018              Colchão              Casa       109,9
# 2           10014            Geladeira  Eletrodomésticos       699,9
# 3           10001           Smartphone       Eletrônicos       899,9
# 4           10004  Máquina Lavar Roupa  Eletrodomésticos        1099
#
#   valor_unitario  quantidade comissao          dt_venda        dt_entrega
# ...

# %%
df = pd.read_excel('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/Vendas.xlsx', sheet_name ='base_vendas')

# %%
df
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  \
# 0                 123456111       José Maria  Vendedor       CL001
# 1                 123456111       José Maria  Vendedor       CL001
# 2                 123456111       José Maria  Vendedor       CL001
# 3                 123456111       José Maria  Vendedor       CL001
# 4                 123456111       José Maria  Vendedor       CL001
# ...                     ...              ...       ...         ...
# 2995              123457113      Victor Hugo  Vendedor       CL004
# 2996              123457113      Victor Hugo  Vendedor       CL004
# 2997              123457113      Victor Hugo  Vendedor       CL004
# 2998              123457113      Victor Hugo  Vendedor       CL004
# 2999              123457113      Victor Hugo  Vendedor       CL004
#
#         nome_loja  codigo_produto    descricao_produto         Categoria  \
# 0     Loja Matriz           10013                Fogão  Eletrodomésticos
# ...

# %%
tabelas = pd.read_html('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/base_vendas.html')

# %%
tabelas[0]
# Out:
#     matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 5               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 6               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 7               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 8               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 9               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 10              123456111       José Maria  Vendedor       CL001  Loja Matriz
# ...

# %%
df = pd.read_xml('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/base_vendas.xml')

# %%
df
# Out:
#       index  matricula_funcionario nome_funcionario     cargo codigo_loja  \
# 0         0              123456111       José Maria  Vendedor       CL001
# 1         1              123456111       José Maria  Vendedor       CL001
# 2         2              123456111       José Maria  Vendedor       CL001
# 3         3              123456111       José Maria  Vendedor       CL001
# 4         4              123456111       José Maria  Vendedor       CL001
# ...     ...                    ...              ...       ...         ...
# 2995   2995              123457113      Victor Hugo  Vendedor       CL004
# 2996   2996              123457113      Victor Hugo  Vendedor       CL004
# 2997   2997              123457113      Victor Hugo  Vendedor       CL004
# 2998   2998              123457113      Victor Hugo  Vendedor       CL004
# 2999   2999              123457113      Victor Hugo  Vendedor       CL004
#
#         nome_loja  codigo_produto    descricao_produto         categoria  \
# ...

# %%
df = pd.read_json('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/base_vendas.json')

# %%
df
# Out:
#       matricula_funcionario Nome Funcionario     Cargo codigo_loja  \
# 0                 123456111       José Maria  Vendedor       CL001
# 1                 123456111       José Maria  Vendedor       CL001
# 2                 123456111       José Maria  Vendedor       CL001
# 3                 123456111       José Maria  Vendedor       CL001
# 4                 123456111       José Maria  Vendedor       CL001
# ...                     ...              ...       ...         ...
# 2995              123457113      Victor Hugo  Vendedor       CL004
# 2996              123457113      Victor Hugo  Vendedor       CL004
# 2997              123457113      Victor Hugo  Vendedor       CL004
# 2998              123457113      Victor Hugo  Vendedor       CL004
# 2999              123457113      Victor Hugo  Vendedor       CL004
#
#         nome_loja  codigo_produto    descricao_produto         Categoria  \
# 0     Loja Matriz           10013                Fogão  Eletrodomésticos
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/vendas.db')

# %%
df = pd.read_sql_query('select *from pedidos', conn)

# %%
df
# Out:
#    matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4              123456111       José Maria  Vendedor       CL001  Loja Matriz
# ..                   ...              ...       ...         ...          ...
# 95             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 96             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 97             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 98             123456111       José Maria  Vendedor       CL001  Loja Matriz
# 99             123456111       José Maria  Vendedor       CL001  Loja Matriz
#
# ...

# %%
df.descricao_produto.unique()
# Out:
# array(['Fogão', 'Colchão', 'Geladeira', 'Smartphone',
#        'Máquina Lavar Roupa', 'Fritadeira elétrica', 'Aspirador de pó',
#        'Cama Box', 'Televisão', 'Guarda Roupa', 'Impressora', 'Cafeteira',
#        'Microondas', 'Tablet', 'Processador de alimentos',
#        'Ferro de passar', 'Sofá', 'Notebook', 'Batedeira',
#        'Liquidificador'], dtype=object)

# %%
df = pd.read_hdf('./02 - Biblioteca Pandas/08 - Pandas - Carregando Dados/datasets/base_vendas.h5')

# %%
df
# Out:
#     matricula_funcionario Nome Funcionario     Cargo codigo_loja    nome_loja  \
# 0               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 1               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 2               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 3               123456111       José Maria  Vendedor       CL001  Loja Matriz
# 4               123456111       José Maria  Vendedor       CL001  Loja Matriz
# ..                    ...              ...       ...         ...          ...
# 95              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 96              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 97              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 98              123456111       José Maria  Vendedor       CL001  Loja Matriz
# 99              123456111       José Maria  Vendedor       CL001  Loja Matriz
#
# ...
